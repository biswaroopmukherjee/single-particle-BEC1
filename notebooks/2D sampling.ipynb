# %% [markdown]
# ## 2D Gaussian Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
## Random sampling from an elliptical gaussian distro

# Create some random numbers
n = 100000
x = np.random.randn(n)
y = (1.5 * x) + np.random.randn(n)
 
# Estimate the 2D histogram
nbins = 200
H, xedges, yedges = np.histogram2d(x,y,bins=nbins)

# # Mask zeros
# Hmasked = np.ma.masked_where(H==0,H) # Mask pixels with a value 

# Plot 2D histogram using pcolor
fig2 = plt.figure()
plt.pcolormesh(xedges,yedges,H)
plt.xlabel('x')
plt.ylabel('y')
cbar = plt.colorbar()
cbar.ax.set_ylabel('Counts')
plt.show()

# %% [markdown]
# ## 2D uniform circle distribution

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


# Create some random numbers
n = 100000
r = np.random.rand(n)
theta = 2*math.pi*np.random.rand(n)

xpoints = np.sqrt(r)*np.cos(theta)
ypoints = np.sqrt(r)*np.sin(theta)
 
# Estimate the 2D histogram
nbins = 200
H, xedges, yedges = np.histogram2d(xpoints,ypoints,bins=nbins)

# Plot 2D histogram using pcolor
fig2 = plt.figure()
plt.pcolormesh(xedges,yedges,H)
plt.xlabel('x')
plt.ylabel('y')
cbar = plt.colorbar()
cbar.ax.set_ylabel('Counts')
plt.show()
